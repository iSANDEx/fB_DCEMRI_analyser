# %%
import os
import sys
import itk
from json_minify import json_minify # to allow comments in json files
import json
import time
import ants
import glob
import shutil
import pandas as pd
import numpy as np
# import pydicom as pyd
# import dicom2nifti
from directory_tree import display_tree  # Nice tool to display directory trees (https://pypi.org/project/directory-tree/)

from datetime import timedelta, datetime

# %%
def list_folder_content(path, show_hidden=False):
    if show_hidden:
        ddfldrlst = os.listdir(path)
    else:
        ddfldrlst = list(filter(lambda item: not item.startswith('.'),os.listdir(path)))      
    return ddfldrlst

def display_folder_list(file_list):
    print('\n'.join(f'[{idx}] - {file_idx}' for idx, file_idx in enumerate(file_list)))

def get_path_to_process(full_path):
    print('Folder content:')
    print(display_tree(full_path, header=True, string_rep=True, show_hidden=False, max_depth=2))
    folder_content = list_folder_content(full_path)
    # Ideally we'll have only one sub-folder inside the PreTreatment folder. If more than one, then we have to choose, but by default, we'll select the first one.
    idx_reg = 0
    if len(folder_content) > 1:
        display_folder_list(folder_content)
        idx_sel = input(f'Select the folder with the dataset_to_process to process (0-{len(folder_content)-1} or just press Enter to proceed with sub-folder {folder_content[idx_reg]}):')
        if idx_sel:
            idx_reg = int(idx_sel)
    path2data = os.path.join(full_path, folder_content[idx_reg])
    print(f'Will process {folder_content[idx_reg]}')
    return path2data

def check_time_points(path_to_check, nmax = 6):
    if path_to_check is not None:
        nr_of_folders = list_folder_content(path_to_check)
        print('Folder seems Ok:' if len(nr_of_folders)== nmax else f'Error! Check path {path_to_check} is the correct one:')
        display_tree(path_to_check, max_depth=1)
        return nr_of_folders if len(nr_of_folders) == nmax else None
    else:
        return None

def add_prefix_to_filename(full_path, prefix=None):
    # Assume the last part of the path is the filename (with extension)
    file_path, file_name_ext = os.path.split(full_path)
    if prefix:
        updated_filename = '_'.join([prefix, file_name_ext])
        return os.path.join(file_path, updated_filename)
    else:
        return prefix

def mutual_info_metric(volume1, volume2):
    """
    See https://antspy.readthedocs.io/en/latest/registration.html#ants.image_mutual_information
    For more complex/versatile image comparisons, see https://antspy.readthedocs.io/en/latest/utils.html#ants.image_similarity
    """
    mi_metric = ants.image_mutual_information(volume1, volume2)
    
    return mi_metric

def get_metrics(volume1, volume2, metric='mi', debug=False, sampling_pc=1.0):
    """
    See https://antspy.readthedocs.io/en/latest/utils.html#ants.image_similarity
    For more complex/versatile metrics, see https://antspy.readthedocs.io/en/latest/registration.html#ants.image_mutual_information    
    """
    if debug:
        start_time = time.perf_counter()
        print(''.join(['§']*100))
        print(f'§§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric {metric}...')
    if metric == 'mi':
        val = ants.image_mutual_information(volume1, volume2)
    elif metric == 'mean_sq':
        val = ants.image_similarity(volume1, volume2, metric_type='MeanSquares', sampling_percentage=sampling_pc)
    elif metric == 'dist_corr':
        val = ants.image_similarity(volume1, volume2, metric_type='Correlation', sampling_percentage=sampling_pc)
    elif metric == 'mattes_mi':
        val = ants.image_similarity(volume1, volume2, metric_type='MattesMutualInformation', sampling_percentage=sampling_pc)
    elif metric == 'joint_hist_mi':
        val = ants.image_similarity(volume1, volume2, metric_type='JointHistogramMutualInformation', sampling_percentage=sampling_pc)
    else:
        val = None

    if debug:
        end_time = time.perf_counter()
        elp_time = end_time - start_time
        print(f'§§§§§§§§§§§§ GET_METRICS: Elapsed time: {elp_time:0.2f}[s]')
        print(''.join(['§']*100))


    return val

def getenv():
    """
    Requires sys and os modules:
    import sys
    import os
    Possible values for sys.platform are (https://docs.python.org/3/library/sys.html & https://stackoverflow.com/questions/446209/possible-values-from-sys-platform)
    ┍━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━┑
    │  System             │ Value               │
    ┝━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
    │ Linux               │ linux or linux2 (*) │
    │ Windows             │ win32               │
    │ Windows/Cygwin      │ cygwin              │
    │ Windows/MSYS2       │ msys                │
    │ Mac OS X            │ darwin              │
    │ OS/2                │ os2                 │
    │ OS/2 EMX            │ os2emx              │
    │ RiscOS              │ riscos              │
    │ AtheOS              │ atheos              │
    │ FreeBSD 7           │ freebsd7            │
    │ FreeBSD 8           │ freebsd8            │
    │ FreeBSD N           │ freebsdN            │
    │ OpenBSD 6           │ openbsd6            │
    │ AIX                 │ aix (**)            │
    ┕━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━┙
    """
    if sys.platform == 'win32':
        env_home = 'HOMEPATH'
    elif (sys.platform == 'darwin') | (sys.platform == 'linux'):
        env_home = 'HOME'
    HOMEPATH = os.getenv(env_home)
    
    return HOMEPATH

def check_path_exist(path, file=False):
    """
    Flag FILE indicates the path contains a file name (FLAG=TRUE) or the path only points to a folder (FLAG=FALSE (Default))
    """
    if file:
        is_path = os.path.isfile(path)
    else:
        is_path = os.path.isdir(path)

    print(f'{"OK:" if is_path else "ERROR:"} Path to {"file" if file else "folder"} {path} does{"" if is_path else " NOT"} exist')

    return is_path

# %%
HOMEPATH = getenv()
SRCPATH = os.path.join(HOMEPATH, 'Data', 'fMRIBreastData')

DCMSRCFLDR = 'StudyData'
TESTSFLDR = 'tests'
REFTEST = 'Test000'
OUTPUTFLDR = f'{os.sep}'.join(['output', 'reg_csv'])
IMGSRCFLDR = 'datasets'

input_path = os.path.join(SRCPATH, TESTSFLDR)
save_path = os.path.join(SRCPATH, OUTPUTFLDR)
# Check whether the folder SAVEPATH exists or not, if not, attempts to create it
os.makedirs(save_path, exist_ok=True)

# %%
DEBUGMODE = True
BATCHMODE = True # TRUE: it runs all dataset within INPUT_PATH; FALSE (DEFAULT): allows to pick a specific dataset to register

# %%
# Datafolder structure is:
display_tree(input_path)
# Out:
# tests/
# ├── Test000/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   └── landmarks/
# │   │   │   │       ├── CR-Post-Treatment-20230120-Slices077-115-Frame002.jpg
# │   │   │   │       ├── RoiSet-Frame001.zip
# │   │   │   │       └── RoiSet-Frame002.zip
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── CR-Pre-Treatment-20221212.nii.gz
# │   │   │       └── landmarks/
# │   │   │           ├── CR-Pre-Treatment-20221212-Slices-071-105-106-Frame002.jpg
# │   │   │           ├── RoiSet-Frame001.zip
# │   │   │           └── RoiSet-Frame002.zip
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── DC-Post-Treatment-20230726.nii.gz
# │   │   │   │   └── landmarks/
# │   │   │   │       ├── DC-Post-Treatment-20230726-Slices069-Frame002.jpg
# │   │   │   │       ├── RoiSet-Frame001.zip
# │   │   │   │       └── RoiSet-Frame002.zip
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── DC-Pre-Treatment-20230621.nii.gz
# │   │   │       └── landmarks/
# │   │   │           ├── DC-Pre-Treatment-20230621-Slices055-Frame002.jpg
# │   │   │           ├── RoiSet-Frame001.zip
# │   │   │           └── RoiSet-Frame002.zip
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   │   └── landmarks/
# │   │   │   │       └── Eilb post treatment.jpg
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── EilB-Pre-Treatment-20230621.nii.gz
# │   │   │       └── landmarks/
# │   │   │           └── EilB Pre-treatment.jpg
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── GL-Post-Treatment-20230720.nii.gz
# │   │   │       └── landmarks/
# │   │   │           ├── GL-Post-Treatment-20230720-Slices060-Frame002.jpg
# │   │   │           ├── RoiSet-Frame001.zip
# │   │   │           └── RoiSet-Frame002.zip
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── JB-Post-Treatment-20230511.nii.gz
# │   │   │   │   └── landmarks/
# │   │   │   │       └── JB Post- Treatment.jpg
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── JB-Pre-Treatment-20230405.nii.gz
# │   │   │       └── landmarks/
# │   │   │           └── JB pre-treatment.jpg
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── landmarks/
# │   │   │   │   │   ├── NE-Post-Treatment-20221215-Slices056-Frame004.jpg
# │   │   │   │   │   ├── RoiSet-Frame001.zip
# │   │   │   │   │   └── RoiSet-Frame002.zip
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── landmarks/
# │   │   │       │   ├── NE-Pre-Treatment-20221026-Slices054-Frame004.jpg
# │   │   │       │   ├── RoiSet-Frame001.zip
# │   │   │       │   └── RoiSet-Frame002.zip
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── landmarks/
# │   │       │   │   ├── RICE001-20221026-Slices054-Frame004.jpg
# │   │       │   │   ├── RoiSet-Frame001.zip
# │   │       │   │   └── RoiSet-Frame002.zip
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── landmarks/
# │   │           │   ├── RICE001-20221215-Slice056-Frame004.jpg
# │   │           │   ├── RoiSet-Frame001.zip
# │   │           │   └── RoiSet-Frame002.zip
# │   │           └── RICE001-20221215.nii.gz
# │   └── description.json
# ├── Test001/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   ├── CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   ├── deformation_map_ants_fixedVol001_CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   ├── deformation_map_elastix_fixedVol001_CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   ├── inter_visit_aligned_ants_fixedVol001_CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   ├── inter_visit_aligned_elastix_fixedVol001_CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   ├── slice111.csv
# │   │   │   │   └── slice112.csv
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 0073-0471-0591.roi
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       ├── CR-Pre-Treatment-20221212.nii.gz
# │   │   │       ├── RoiSet.zip
# │   │   │       ├── TumourSI_Slice105.csv
# │   │   │       └── tumourSI_slice105.roi
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   ├── parameters/
# │   │   ├── CR-ANON68760_inter_visit_parameters_ANTs.json
# │   │   ├── CR-ANON68760_inter_visit_parameters_Par0032_bsplines.txt
# │   │   ├── CR-ANON68760_inter_visit_parameters_Par0032_rigid.txt
# │   │   ├── Par0032_bsplines.txt
# │   │   └── Par0032_rigid.txt
# │   └── rois/
# │       ├── CR-Pre-Treatment-20221212-box-tumour.zip
# │       └── CR-Pre-Treatment-20221212-tumour.zip
# ├── Test002/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       ├── CR-Pre-Treatment-20221212.nii.gz
# │   │   │       ├── TumourSI_Slice105.csv
# │   │   │       └── tumourSI_slice105.roi
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       ├── Par0032_bsplines.txt
# │       └── Par0032_rigid.txt
# ├── Test003/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       ├── Par0032_bsplines.txt
# │       └── Par0032_rigid.txt
# ├── Test004/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       ├── Par0032_bsplines.txt
# │       └── Par0032_rigid.txt
# ├── Test005/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   ├── random_seed_42_run001_TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   │   ├── random_seed_42_run002_TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   │   ├── Test_ConstantRandomSeed_concat_volume.nii.gz
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── TP01_FIXED_601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── TP02_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── TP03_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── TP04_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── TP05_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── TP06_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       └── DefaultANTspy.json
# ├── Test006/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# ...
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       ├── Par0032_bsplines.txt
# │       └── Par0032_rigid.txt
# ├── Test012/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   ├── CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   ├── deformation_map_ants_fixedVol002_CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   ├── deformation_map_elastix_fixedVol002_CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   ├── inter_visit_aligned_ants_fixedVol002_CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   └── inter_visit_aligned_elastix_fixedVol002_CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       ├── CR-ANON68760_inter_visit_parameters_ANTs.json
# │       ├── CR-ANON68760_inter_visit_parameters_Par0032_bsplines.txt
# │       ├── CR-ANON68760_inter_visit_parameters_Par0032_rigid.txt
# │       └── PDefaultANTspy.json
# └── Test013/
#     ├── datasets/
#     │   ├── DC-ANON97378/
#     │   │   ├── DC-Post-Treatment-20230726/
#     │   │   │   ├── 301/
#     │   │   │   │   ├── 1/
#     │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
#     │   │   │   │   ├── 2/
#     │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
#     │   │   │   │   ├── 3/
#     │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
#     │   │   │   │   ├── 4/
#     │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
#     │   │   │   │   ├── 5/
#     │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
#     │   │   │   │   └── 6/
#     │   │   │   │       └── 301_dyn_ethrive.nii.gz
#     │   │   │   └── DC-Post-Treatment-20230726.nii.gz
#     │   │   └── DC-Pre-Treatment-20230621/
#     │   │       ├── 301/
#     │   │       │   ├── 1/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   ├── 2/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   ├── 3/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   ├── 4/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   ├── 5/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   └── 6/
#     │   │       │       └── 301_dyn_ethrive.nii.gz
#     │   │       └── DC-Pre-Treatment-20230621.nii.gz
#     │   ├── GL-ANON99397/
#     │   │   └── GL-Post-Treatment-20230720/
#     │   │       ├── 301/
#     │   │       │   ├── 1/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   ├── 2/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   ├── 3/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   ├── 4/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   ├── 5/
#     │   │       │   │   └── 301_dyn_ethrive.nii.gz
#     │   │       │   └── 6/
#     │   │       │       └── 301_dyn_ethrive.nii.gz
#     │   │       └── GL-Post-Treatment-20230720.nii.gz
#     │   └── JB-ANON18218/
#     │       └── JB-Pre-Treatment-20230405/
#     │           └── 301/
#     │               ├── 1/
#     │               │   └── 301_dyn_ethrive.nii.gz
#     │               ├── 2/
#     │               │   └── 301_dyn_ethrive.nii.gz
#     │               ├── 3/
#     │               │   └── 301_dyn_ethrive.nii.gz
#     │               └── 4/
#     ├── description.json
#     └── parameters/
#         └── DefaultANTspy.json

# %%
# TEST000 contains just the raw (unregistered) data. Any other tests is described in the corresponding descrption.json file
tests_available = sorted(list_folder_content(input_path))
if not BATCHMODE:
    default_idx_test = 0
    print('Select a folder from the tests available:')
    display_folder_list(tests_available)
    test_idx = input(f'Pick a valid index to select a Test folder {tuple(range(len(tests_available)))} or type "x" to use the default:')
    if test_idx == 'x':
        print(f'Selecting index {default_idx_test} (default value)')
        test_idx = default_idx_test
    else:
        test_idx = int(test_idx)
    tests_to_process = [tests_available[test_idx]]
    print(f'Will process test {tests_to_process[0]}')
else:
    tests_to_process = tests_available
    # Test010 is not a valid registration test, but just some individual testings (should be deleted at some point)
    # if exist_test_010
    # tests_to_process.remove('Test010')
    
    print('Will process all valid test data in the folder:')
    print('\n'.join(tests_to_process))
# Out:
# Will process all valid test data in the folder:
# Test000
# Test001
# Test002
# Test003
# Test004
# Test005
# Test006
# Test007
# Test008
# Test009
# Test010
# Test011
# Test012
# Test013

# %%
# Within Test the image data is in DATASETS and here we pick up a patient and will process all visits
if not BATCHMODE:
    path_to_patients = os.path.join(input_path, tests_to_process[0], IMGSRCFLDR)
    patient_list = sorted(list_folder_content(path_to_patients))
    print('Select a a patient from the list:')
    display_folder_list(patient_list)
    patient_idx = input(f'Pick a valid index to select a Patient {tuple(range(len(patient_list)))} or type "a" to select all:')
    if patient_idx == 'a':
        patients_to_process = patient_list
        print(f'Will process all patients in the test folder')
    else:
        patient_idx = int(patient_idx)
        patients_to_process = [patient_list[patient_idx]]
        print(f'Will process Patient {patients_to_process[0]}')

# %%
# Setup DataFrame to store the results
statistics = {'mi': 'Mutual Information',
              'mean_sq': 'Mean Squares', 
              'dist_corr':'Correlation', 
              'mattes_mi':'Mattes Mutual Information', 
              'joint_hist_mi':'Joint Histogram Mutual Information'
              }
sampling_fraction = 0.85

hdr_row = ['TestNro', 'PatientID', 'PatientVisit', 'RegistrationMethod', 'FixedVolume', 'Registered2Itself', 'BiasCorrection', 'HistogramMatching', 'TimePoint'] + list(statistics.values())

stats_rows = []

# %%
# TODO: Add the option to append the output to an existing dataframe, but only when running NOT in Batch Mode
# Now loop over the test(s) and patient(s) - even if not running in Batch Mode (in this case is a list of size 1, which can still be looped through)
print(f'Time at the start: {time.ctime()}')
init_time = time.perf_counter()
for test_to_process in tests_to_process:
    # Load the description file from the corresponding test: 
    description = json.loads(open(os.path.join(input_path, test_to_process, 'description.json')).read())
    # Identify the fixed volume (remember that the index is volume-1)
    # If Test000 (i.e. unregistered data), we need to generate the metrics for both fixed volumes, 1 & 2:
    reference_volume = description['Registration Details']['reference volume']
    is_reg_to_itself = description['Registration Details']['register fixed']
    reg_method = description['Registration Details']['algorithm']
    bias_correction = description['Preprocessing']['bias_correction']
    histogram_matching = description['Preprocessing']['histogram_matching']

    ref_vol_idx = reference_volume - 1
    path_to_dataset = os.path.join(input_path, test_to_process, IMGSRCFLDR)
    if BATCHMODE:
        patients_to_process = sorted(list_folder_content(path_to_dataset))

    for patient_to_process in patients_to_process:
        folders_in_patient = os.path.join(path_to_dataset, patient_to_process)
        visits = list_folder_content(folders_in_patient)
        for visit in visits:
            path_to_nii = os.path.join(folders_in_patient, visit)
            nii_folder_name = '.'.join([visit, 'nii','gz'])
            nii_full_path =  os.path.join(path_to_nii, nii_folder_name)
            # Does the 4D volume exist?
            exist_nii = os.path.isfile(nii_full_path)
            if exist_nii:
                print(f'Processing file {nii_full_path}  ({test_to_process}, {nii_folder_name}), please wait...')
                # Load the volume:
                if DEBUGMODE:
                        print(''.join(['*']*100))
                        print('Timing IMAGE_READ (vol_to_proc)...')
                        start_time = time.perf_counter()
                vol_to_process = ants.image_read(nii_full_path)
                spacing, origin = [vol_to_process.spacing[:-1], vol_to_process.origin[:-1]]
                if DEBUGMODE:
                        end_time = time.perf_counter()
                        elp_time = end_time - start_time
                        print(f'\tElapsed time: {elp_time:0.2f}[s]')
                        print(''.join(['*']*100))

                # To ensure a comparable comparison across tests, load the reference volume from the unregistered data:
                print(f"path to fixed volume: {nii_full_path.replace(test_to_process,'Test000')}")
                if DEBUGMODE:
                        print(''.join(['*']*100))
                        print('Timing IMAGE_READ (fixed_volume)...')
                        start_time = time.perf_counter()
                fixed_volume = ants.image_read(nii_full_path.replace(test_to_process,'Test000'))
                if DEBUGMODE:
                        end_time = time.perf_counter()
                        elp_time = end_time - start_time
                        print(f'\tElapsed time: {elp_time:0.2f}[s]')
                        print(''.join(['*']*100))

                ref_vol = vol_to_process[:, :, :, ref_vol_idx]
                if test_to_process == 'Test000':
                      ref_vol2 = fixed_volume[:, :, :, 1]
                if DEBUGMODE:
                        print(''.join(['*']*100))
                        print('Timing Image Conversion FROM_NUMPY (fixed_volume)...')
                        start_time = time.perf_counter()
                ref_3d = ants.from_numpy(ref_vol, 
                                        spacing=spacing,
                                        origin=origin)
                if test_to_process == 'Test000':
                      ref_3d_frame2 = ants.from_numpy(ref_vol2, 
                                        spacing=spacing,
                                        origin=origin)
                      
                if DEBUGMODE:
                        end_time = time.perf_counter()
                        elp_time = end_time - start_time
                        print(f'\tElapsed time: {elp_time:0.2f}[s]')
                        print(''.join(['*']*100))

                for idx_time in range(vol_to_process.shape[-1]):
                    if DEBUGMODE:
                            print(''.join(['*']*100))
                            print('Timing Image Conversion FROM_NUMPY (moving_volume)...')
                            start_time = time.perf_counter()
                    mov_3d = ants.from_numpy(vol_to_process[:,:,:,idx_time],
                                            spacing=spacing, 
                                            origin=origin)
                    print(f'Comparison between t[{ref_vol_idx+1}] & t[{idx_time+1}]:')
                    row_to_append = [test_to_process, 
                                     patient_to_process,
                                     visit, 
                                     reg_method,
                                     reference_volume, 
                                     is_reg_to_itself, 
                                     bias_correction,
                                     histogram_matching,
                                     idx_time+1]
                    if test_to_process == 'Test000':
                        row_to_append2 = [test_to_process, 
                                        patient_to_process,
                                        visit, 
                                        reg_method,
                                        2, 
                                        is_reg_to_itself,
                                        bias_correction,
                                        histogram_matching,
                                        idx_time+1]
                        row_to_append3 = [test_to_process, 
                                        patient_to_process,
                                        visit, 
                                        reg_method,
                                        reference_volume, 
                                        True, 
                                        bias_correction,
                                        histogram_matching,
                                        idx_time+1]
                        row_to_append4 = [test_to_process, 
                                        patient_to_process,
                                        visit, 
                                        reg_method,
                                        2, 
                                        True, 
                                        bias_correction,
                                        histogram_matching,
                                        idx_time+1]
                          
                    if DEBUGMODE:
                            end_time = time.perf_counter()
                            elp_time = end_time - start_time
                            print(f'\tElapsed time: {elp_time:0.2f}[s]')
                            print(''.join(['*']*100))
                    if DEBUGMODE:
                            print(''.join(['*']*100))
                            print('Timing Stats calculation ...')
                            start_time = time.perf_counter()
                    for statsID, statsName in statistics.items():
                        statsVal = get_metrics(ref_3d, mov_3d, metric=statsID, debug=DEBUGMODE, sampling_pc=sampling_fraction)
                        row_to_append.append(statsVal)
                        if test_to_process == 'Test000':
                            statsVal2 = get_metrics(ref_3d_frame2, mov_3d, metric=statsID, debug=DEBUGMODE, sampling_pc=sampling_fraction)
                            row_to_append2.append(statsVal2)
                            row_to_append3.append(statsVal)
                            row_to_append4.append(statsVal2)
                    if idx_time == ref_vol_idx:
                        print('(As positive control, the metric(s) are also calculated between the fixed volume and itself)')
                    if DEBUGMODE:
                        end_time = time.perf_counter()
                        elp_time = end_time - start_time
                        print(f'\tElapsed time: {elp_time:0.2f}[s]')
                        print(row_to_append)
                        if test_to_process == 'Test000':
                            print(row_to_append2)
                            print(row_to_append3)
                            print(row_to_append4)
                        print(''.join(['*']*100))

                    stats_rows.append(row_to_append)
                    if test_to_process == 'Test000':
                          stats_rows.append(row_to_append2)
                          stats_rows.append(row_to_append3)
                          stats_rows.append(row_to_append4)
            else:
                print(f'File {nii_folder_name} in {path_to_nii} does not exist, nothing done')
                continue
            print('Just taking a break...')
            time.sleep(1)
            print('ok, ready to go...')

final_time = time.perf_counter()
print('Creating the dataframe and saving the results...')
df = pd.DataFrame(columns=hdr_row, data=stats_rows)
print(df.head())
today = datetime.now().strftime('%Y%m%d')
if BATCHMODE:
    csv_filename = f'summary_results_metrics_{today}_sampling_frac_{sampling_fraction}.csv'
else:
    csv_filename = f'summary_results_metrics_subset_of_{tests_to_process[0]}_{today}_sampling_frac_{sampling_fraction}.csv'
df.to_csv(os.path.join(save_path, csv_filename), index_label='IdxKey')
elapsed_time = final_time - init_time
print(f'Elapsed time to summarise the datasets: {elapsed_time:0.2f}[s] ({timedelta(seconds=elapsed_time)})')
print(f'Time at the end: {time.ctime()}')
print('All done, check the results. Bye!')
# Out:
# Time at the start: Wed Mar 27 16:33:18 2024
# Processing file /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/CR-ANON68760/CR-Pre-Treatment-20221212/CR-Pre-Treatment-20221212.nii.gz  (Test000, CR-Pre-Treatment-20221212.nii.gz), please wait...
# ****************************************************************************************************
# Timing IMAGE_READ (vol_to_proc)...
# 	Elapsed time: 3.89[s]
# ****************************************************************************************************
# path to fixed volume: /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/CR-ANON68760/CR-Pre-Treatment-20221212/CR-Pre-Treatment-20221212.nii.gz
# ****************************************************************************************************
# Timing IMAGE_READ (fixed_volume)...
# 	Elapsed time: 3.83[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (fixed_volume)...
# 	Elapsed time: 0.44[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[1]:
# 	Elapsed time: 0.08[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 4.89[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 4.16[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.00[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.36[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.36[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.38[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.97[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.75[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.63[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# (As positive control, the metric(s) are also calculated between the fixed volume and itself)
# 	Elapsed time: 90.16[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, False, None, False, 1, -1.1431462905704368, 0.0, -1.0, -1.4358234405517578, -0.47401171922683716]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, False, None, False, 1, -0.5073886960485164, 178489.015625, -0.5936515927314758, -0.6297764778137207, -0.303646057844162]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, True, None, False, 1, -1.1431462905704368, 0.0, -1.0, -1.4358234405517578, -0.47401171922683716]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, True, None, False, 1, -0.5073886960485164, 178489.015625, -0.5936515927314758, -0.6297764778137207, -0.303646057844162]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[2]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 4.07[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 4.13[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.17[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.25[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.10[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.67[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.85[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.10[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.32[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.52[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 88.19[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, False, None, False, 2, -0.5015544208024358, 178489.015625, -0.5936515927314758, -0.6298865675926208, -0.303646057844162]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, False, None, False, 2, -1.1645617881157628, 0.0, -1.0, -1.45902419090271, -0.4601183831691742]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, True, None, False, 2, -0.5015544208024358, 178489.015625, -0.5936515927314758, -0.6298865675926208, -0.303646057844162]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, True, None, False, 2, -1.1645617881157628, 0.0, -1.0, -1.45902419090271, -0.4601183831691742]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[3]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.95[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.93[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.33[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.30[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.07[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.71[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.14[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.33[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.65[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.92[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 82.32[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, False, None, False, 3, -0.48586224102016445, 174855.796875, -0.5828652381896973, -0.611098051071167, -0.29442036151885986]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, False, None, False, 3, -0.6231609011848945, 72936.0, -0.8308984041213989, -0.7584593296051025, -0.35206109285354614]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, True, None, False, 3, -0.48586224102016445, 174855.796875, -0.5828652381896973, -0.611098051071167, -0.29442036151885986]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, True, None, False, 3, -0.6231609011848945, 72936.0, -0.8308984041213989, -0.7584593296051025, -0.35206109285354614]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[4]:
# 	Elapsed time: 0.12[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.74[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.35[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.45[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.91[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.88[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.77[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.96[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.13[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.38[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 90.24[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, False, None, False, 4, -0.4811257597612439, 165830.21875, -0.5831196904182434, -0.6060187816619873, -0.2893173098564148]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, False, None, False, 4, -0.6272523773694277, 67768.484375, -0.8403981924057007, -0.764949381351471, -0.3554946482181549]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, True, None, False, 4, -0.4811257597612439, 165830.21875, -0.5831196904182434, -0.6060187816619873, -0.2893173098564148]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, True, None, False, 4, -0.6272523773694277, 67768.484375, -0.8403981924057007, -0.764949381351471, -0.3554946482181549]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[5]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.88[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.77[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.76[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.87[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.16[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.93[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.02[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.84[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.21[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.49[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 84.96[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, False, None, False, 5, -0.48059873830387967, 159194.03125, -0.5934348106384277, -0.6051721572875977, -0.2866603136062622]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, False, None, False, 5, -0.6235160909004336, 68223.953125, -0.8389508724212646, -0.760520339012146, -0.35129648447036743]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, True, None, False, 5, -0.48059873830387967, 159194.03125, -0.5934348106384277, -0.6051721572875977, -0.2866603136062622]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, True, None, False, 5, -0.6235160909004336, 68223.953125, -0.8389508724212646, -0.760520339012146, -0.35129648447036743]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[6]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.64[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.93[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.30[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.12[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.94[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.64[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.63[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.16[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.50[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.45[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 88.31[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, False, None, False, 6, -0.48153900220631507, 152432.328125, -0.6043466925621033, -0.6066174507141113, -0.28737473487854004]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, False, None, False, 6, -0.5902991039234096, 85642.4375, -0.798643171787262, -0.7222625017166138, -0.33535388112068176]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 1, True, None, False, 6, -0.48153900220631507, 152432.328125, -0.6043466925621033, -0.6066174507141113, -0.28737473487854004]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 'Raw', 2, True, None, False, 6, -0.5902991039234096, 85642.4375, -0.798643171787262, -0.7222625017166138, -0.33535388112068176]
# ****************************************************************************************************
# Just taking a break...
# ok, ready to go...
# Processing file /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/CR-ANON68760/CR-Post-Treatment-20230120/CR-Post-Treatment-20230120.nii.gz  (Test000, CR-Post-Treatment-20230120.nii.gz), please wait...
# ****************************************************************************************************
# Timing IMAGE_READ (vol_to_proc)...
# 	Elapsed time: 3.30[s]
# ****************************************************************************************************
# path to fixed volume: /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/CR-ANON68760/CR-Post-Treatment-20230120/CR-Post-Treatment-20230120.nii.gz
# ****************************************************************************************************
# Timing IMAGE_READ (fixed_volume)...
# 	Elapsed time: 3.50[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (fixed_volume)...
# 	Elapsed time: 0.26[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[1]:
# 	Elapsed time: 0.09[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.92[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.43[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.45[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.05[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.55[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.06[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.65[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.22[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.07[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.70[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# (As positive control, the metric(s) are also calculated between the fixed volume and itself)
# 	Elapsed time: 87.11[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 1, False, None, False, 1, -1.135177710088157, 0.0, -1.0, -1.4151239395141602, -0.473031222820282]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 2, False, None, False, 1, -0.4974622358769965, 252889.390625, -0.5848492383956909, -0.6239409446716309, -0.2810923457145691]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 1, True, None, False, 1, -1.135177710088157, 0.0, -1.0, -1.4151239395141602, -0.473031222820282]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 2, True, None, False, 1, -0.4974622358769965, 252889.390625, -0.5848492383956909, -0.6239409446716309, -0.2810923457145691]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[2]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.67[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.57[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.08[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.44[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.27[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.30[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.69[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 11.75[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.28[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.50[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 87.55[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 1, False, None, False, 2, -0.49135029623505766, 252889.390625, -0.5848492383956909, -0.6143882870674133, -0.2810923457145691]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 2, False, None, False, 2, -1.0882097429455053, 0.0, -1.0, -1.383167028427124, -0.39157938957214355]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 1, True, None, False, 2, -0.49135029623505766, 252889.390625, -0.5848492383956909, -0.6143882870674133, -0.2810923457145691]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 2, True, None, False, 2, -1.0882097429455053, 0.0, -1.0, -1.383167028427124, -0.39157938957214355]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[3]:
# 	Elapsed time: 0.13[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.01[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.02[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.56[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.63[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.80[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.86[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.91[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.84[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.40[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.72[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 88.73[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 1, False, None, False, 3, -0.4804716586087253, 237132.4375, -0.5845489501953125, -0.6023693680763245, -0.27475857734680176]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 2, False, None, False, 3, -0.6147213879194189, 87854.015625, -0.8514161109924316, -0.7564657330513, -0.30847257375717163]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 1, True, None, False, 3, -0.4804716586087253, 237132.4375, -0.5845489501953125, -0.6023693680763245, -0.27475857734680176]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 2, True, None, False, 3, -0.6147213879194189, 87854.015625, -0.8514161109924316, -0.7564657330513, -0.30847257375717163]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[4]:
# 	Elapsed time: 0.16[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.89[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.95[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.46[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.48[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.37[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.71[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.70[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.77[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.33[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 10.25[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 81.93[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 1, False, None, False, 4, -0.47937551123172223, 233455.28125, -0.5879133939743042, -0.5984841585159302, -0.273113489151001]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 2, False, None, False, 4, -0.5817726573618479, 116981.3515625, -0.8035442233085632, -0.7176909446716309, -0.3101367652416229]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 1, True, None, False, 4, -0.47937551123172223, 233455.28125, -0.5879133939743042, -0.5984841585159302, -0.273113489151001]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 'Raw', 2, True, None, False, 4, -0.5817726573618479, 116981.3515625, -0.8035442233085632, -0.7176909446716309, -0.3101367652416229]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.49[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.39[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.64[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.71[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.47[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.61[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.71[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.70[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 31.67[s]
# ['Test000', 'JB-ANON18218', 'JB-Post-Treatment-20230511', 'Raw', 1, False, None, False, 5, -0.44921809259691836, 157267.625, -0.6629236340522766, -0.6116452813148499, -0.24740247428417206]
# ['Test000', 'JB-ANON18218', 'JB-Post-Treatment-20230511', 'Raw', 2, False, None, False, 5, -0.5142947830910564, 89075.5078125, -0.8086909055709839, -0.6924618482589722, -0.295845627784729]
# ['Test000', 'JB-ANON18218', 'JB-Post-Treatment-20230511', 'Raw', 1, True, None, False, 5, -0.44921809259691836, 157267.625, -0.6629236340522766, -0.6116452813148499, -0.24740247428417206]
# ['Test000', 'JB-ANON18218', 'JB-Post-Treatment-20230511', 'Raw', 2, True, None, False, 5, -0.5142947830910564, 89075.5078125, -0.8086909055709839, -0.6924618482589722, -0.295845627784729]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[6]:
# 	Elapsed time: 0.04[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 1.37[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 1.40[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.45[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 4.12[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 4.02[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.61[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.98[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.98[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.67[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 4.08[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.69[s]
# ['Test000', 'JB-ANON18218', 'JB-Post-Treatment-20230511', 'Raw', 1, False, None, False, 6, -0.4590472311566227, 146373.109375, -0.6945974230766296, -0.6213002800941467, -0.2518543004989624]
# ['Test000', 'JB-ANON18218', 'JB-Post-Treatment-20230511', 'Raw', 2, False, None, False, 6, -0.5047054861648667, 96796.7109375, -0.7916091084480286, -0.679151177406311, -0.29609960317611694]
# ['Test000', 'JB-ANON18218', 'JB-Post-Treatment-20230511', 'Raw', 1, True, None, False, 6, -0.4590472311566227, 146373.109375, -0.6945974230766296, -0.6213002800941467, -0.2518543004989624]
# ['Test000', 'JB-ANON18218', 'JB-Post-Treatment-20230511', 'Raw', 2, True, None, False, 6, -0.5047054861648667, 96796.7109375, -0.7916091084480286, -0.679151177406311, -0.29609960317611694]
# ****************************************************************************************************
# Just taking a break...
# ok, ready to go...
# Processing file /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/NE-ANON89073/NE-Pre-Treatment-20221026/NE-Pre-Treatment-20221026.nii.gz  (Test000, NE-Pre-Treatment-20221026.nii.gz), please wait...
# ****************************************************************************************************
# Timing IMAGE_READ (vol_to_proc)...
# 	Elapsed time: 4.10[s]
# ****************************************************************************************************
# path to fixed volume: /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/NE-ANON89073/NE-Pre-Treatment-20221026/NE-Pre-Treatment-20221026.nii.gz
# ****************************************************************************************************
# Timing IMAGE_READ (fixed_volume)...
# 	Elapsed time: 4.29[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (fixed_volume)...
# 	Elapsed time: 0.40[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[1]:
# 	Elapsed time: 0.09[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 5.26[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 6.82[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.62[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.35[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.97[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 9.08[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.18[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.09[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.01[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.06[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# (As positive control, the metric(s) are also calculated between the fixed volume and itself)
# 	Elapsed time: 80.44[s]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 'Raw', 1, False, None, False, 1, -1.0880402369156008, 0.0, -1.0, -1.3916738033294678, -0.46220099925994873]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 'Raw', 2, False, None, False, 1, -0.36329299001426374, 295712.0, -0.5049213767051697, -0.48898306488990784, -0.2584514021873474]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 'Raw', 1, True, None, False, 1, -1.0880402369156008, 0.0, -1.0, -1.3916738033294678, -0.46220099925994873]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 'Raw', 2, True, None, False, 1, -0.36329299001426374, 295712.0, -0.5049213767051697, -0.48898306488990784, -0.2584514021873474]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[1] & t[2]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 4.40[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 139
#     137 row_to_append.append(statsVal)
#     138 if test_to_process == 'Test000':
# --> 139     statsVal2 = get_metrics(ref_3d_frame2, mov_3d, metric=statsID, debug=DEBUGMODE, sampling_pc=sampling_fraction)
#     140     row_to_append2.append(statsVal2)
#     141     row_to_append3.append(statsVal)
#
# Cell In[2], line 63, in get_metrics(volume1, volume2, metric, debug, sampling_pc)
#      61     print(f'§§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric {metric}...')
#      62 if metric == 'mi':
# ---> 63     val = ants.image_mutual_information(volume1, volume2)
#      64 elif metric == 'mean_sq':
#      65     val = ants.image_similarity(volume1, volume2, metric_type='MeanSquares', sampling_percentage=sampling_pc)
#
# File ~/.virtualenvs/isandex/lib/python3.10/site-packages/ants/registration/metrics.py:42, in image_mutual_information(image1, image2)
#      39     raise ValueError('Both images must have same dimension')
#      41 libfn = utils.get_lib_fn('antsImageMutualInformation%iD' % image1.dimension)
# ---> 42 return libfn(image1.pointer, image2.pointer)
#
# KeyboardInterrupt:
