# %%
import os
import sys
from json_minify import json_minify # to allow comments in json files
import json
import time
import ants
import glob
import shutil
import pandas as pd
import numpy as np
# import pydicom as pyd
# import dicom2nifti
from directory_tree import display_tree  # Nice tool to display directory trees (https://pypi.org/project/directory-tree/)

from datetime import timedelta

# %%
def list_folder_content(path, show_hidden=False):
    if show_hidden:
        ddfldrlst = os.listdir(path)
    else:
        ddfldrlst = list(filter(lambda item: not item.startswith('.'),os.listdir(path)))      
    return ddfldrlst

def display_folder_list(file_list):
    print('\n'.join(f'[{idx}] - {file_idx}' for idx, file_idx in enumerate(file_list)))

def get_path_to_process(full_path):
    print('Folder content:')
    print(display_tree(full_path, header=True, string_rep=True, show_hidden=False, max_depth=2))
    folder_content = list_folder_content(full_path)
    # Ideally we'll have only one sub-folder inside the PreTreatment folder. If more than one, then we have to choose, but by default, we'll select the first one.
    idx_reg = 0
    if len(folder_content) > 1:
        display_folder_list(folder_content)
        idx_sel = input(f'Select the folder with the dataset_to_process to process (0-{len(folder_content)-1} or just press Enter to proceed with sub-folder {folder_content[idx_reg]}):')
        if idx_sel:
            idx_reg = int(idx_sel)
    path2data = os.path.join(full_path, folder_content[idx_reg])
    print(f'Will process {folder_content[idx_reg]}')
    return path2data

def check_time_points(path_to_check, nmax = 6):
    if path_to_check is not None:
        nr_of_folders = list_folder_content(path_to_check)
        print('Folder seems Ok:' if len(nr_of_folders)== nmax else f'Error! Check path {path_to_check} is the correct one:')
        display_tree(path_to_check, max_depth=1)
        return nr_of_folders if len(nr_of_folders) == nmax else None
    else:
        return None

def add_prefix_to_filename(full_path, prefix=None):
    # Assume the last part of the path is the filename (with extension)
    file_path, file_name_ext = os.path.split(full_path)
    if prefix:
        updated_filename = '_'.join([prefix, file_name_ext])
        return os.path.join(file_path, updated_filename)
    else:
        return prefix

def mutual_info_metric(volume1, volume2):
    """
    See https://antspy.readthedocs.io/en/latest/registration.html#ants.image_mutual_information
    For more complex/versatile image comparisons, see https://antspy.readthedocs.io/en/latest/utils.html#ants.image_similarity
    """
    mi_metric = ants.image_mutual_information(volume1, volume2)
    
    return mi_metric

def get_metrics(volume1, volume2, metric='mi', debug=False, sampling_pc=1.0):
    """
    See https://antspy.readthedocs.io/en/latest/utils.html#ants.image_similarity
    For more complex/versatile metrics, see https://antspy.readthedocs.io/en/latest/registration.html#ants.image_mutual_information    
    """
    if debug:
        start_time = time.perf_counter()
        print(''.join(['§']*100))
        print(f'§§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric {metric}...')
    if metric == 'mi':
        val = ants.image_mutual_information(volume1, volume2)
    elif metric == 'mean_sq':
        val = ants.image_similarity(volume1, volume2, metric_type='MeanSquares', sampling_percentage=sampling_pc)
    elif metric == 'dist_corr':
        val = ants.image_similarity(volume1, volume2, metric_type='Correlation', sampling_percentage=sampling_pc)
    elif metric == 'mattes_mi':
        val = ants.image_similarity(volume1, volume2, metric_type='MattesMutualInformation', sampling_percentage=sampling_pc)
    elif metric == 'joint_hist_mi':
        val = ants.image_similarity(volume1, volume2, metric_type='JointHistogramMutualInformation', sampling_percentage=sampling_pc)
    else:
        val = None

    if debug:
        end_time = time.perf_counter()
        elp_time = end_time - start_time
        print(f'§§§§§§§§§§§§ GET_METRICS: Elapsed time: {elp_time:0.2f}[s]')
        print(''.join(['§']*100))


    return val

def getenv():
    """
    Requires sys and os modules:
    import sys
    import os
    Possible values for sys.platform are (https://docs.python.org/3/library/sys.html & https://stackoverflow.com/questions/446209/possible-values-from-sys-platform)
    ┍━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━┑
    │  System             │ Value               │
    ┝━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
    │ Linux               │ linux or linux2 (*) │
    │ Windows             │ win32               │
    │ Windows/Cygwin      │ cygwin              │
    │ Windows/MSYS2       │ msys                │
    │ Mac OS X            │ darwin              │
    │ OS/2                │ os2                 │
    │ OS/2 EMX            │ os2emx              │
    │ RiscOS              │ riscos              │
    │ AtheOS              │ atheos              │
    │ FreeBSD 7           │ freebsd7            │
    │ FreeBSD 8           │ freebsd8            │
    │ FreeBSD N           │ freebsdN            │
    │ OpenBSD 6           │ openbsd6            │
    │ AIX                 │ aix (**)            │
    ┕━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━┙
    """
    if sys.platform == 'win32':
        env_home = 'HOMEPATH'
    elif (sys.platform == 'darwin') | (sys.platform == 'linux'):
        env_home = 'HOME'
    HOMEPATH = os.getenv(env_home)
    
    return HOMEPATH

def check_path_exist(path, file=False):
    """
    Flag FILE indicates the path contains a file name (FLAG=TRUE) or the path only points to a folder (FLAG=FALSE (Default))
    """
    if file:
        is_path = os.path.isfile(path)
    else:
        is_path = os.path.isdir(path)

    print(f'{"OK:" if is_path else "ERROR:"} Path to {"file" if file else "folder"} {path} does{"" if is_path else " NOT"} exist')

    return is_path

# %%
HOMEPATH = getenv()
SRCPATH = os.path.join(HOMEPATH, 'Data', 'fMRIBreastData')

DCMSRCFLDR = 'StudyData'
TESTSFLDR = 'tests'
REFTEST = 'Test000'
OUTPUTFLDR = 'results'
IMGSRCFLDR = 'datasets'

input_path = os.path.join(SRCPATH, TESTSFLDR)
save_path = os.path.join(SRCPATH, OUTPUTFLDR)
# Check whether the folder SAVEPATH exists or not, if not, attempts to create it
os.makedirs(save_path, exist_ok=True)

# %%
DEBUGMODE = True
BATCHMODE = True # TRUE: it runs all dataset within INPUT_PATH; FALSE (DEFAULT): allows to pick a specific dataset to register

# %%
# Datafolder structure is:
display_tree(input_path)
# Out:
# tests/
# ├── Test000/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   └── landmarks/
# │   │   │   │       ├── CR-Post-Treatment-20230120-Slices077-115-Frame002.jpg
# │   │   │   │       ├── RoiSet-Frame001.zip
# │   │   │   │       └── RoiSet-Frame002.zip
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── CR-Pre-Treatment-20221212.nii.gz
# │   │   │       └── landmarks/
# │   │   │           ├── CR-Pre-Treatment-20221212-Slices-071-105-106-Frame002.jpg
# │   │   │           ├── RoiSet-Frame001.zip
# │   │   │           └── RoiSet-Frame002.zip
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── DC-Post-Treatment-20230726.nii.gz
# │   │   │   │   └── landmarks/
# │   │   │   │       ├── DC-Post-Treatment-20230726-Slices069-Frame002.jpg
# │   │   │   │       ├── RoiSet-Frame001.zip
# │   │   │   │       └── RoiSet-Frame002.zip
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── DC-Pre-Treatment-20230621.nii.gz
# │   │   │       └── landmarks/
# │   │   │           ├── DC-Pre-Treatment-20230621-Slices055-Frame002.jpg
# │   │   │           ├── RoiSet-Frame001.zip
# │   │   │           └── RoiSet-Frame002.zip
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   │   └── landmarks/
# │   │   │   │       └── Eilb post treatment.jpg
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── EilB-Pre-Treatment-20230621.nii.gz
# │   │   │       └── landmarks/
# │   │   │           └── EilB Pre-treatment.jpg
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── GL-Post-Treatment-20230720.nii.gz
# │   │   │       └── landmarks/
# │   │   │           ├── GL-Post-Treatment-20230720-Slices060-Frame002.jpg
# │   │   │           ├── RoiSet-Frame001.zip
# │   │   │           └── RoiSet-Frame002.zip
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── JB-Post-Treatment-20230511.nii.gz
# │   │   │   │   └── landmarks/
# │   │   │   │       └── JB Post- Treatment.jpg
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── JB-Pre-Treatment-20230405.nii.gz
# │   │   │       └── landmarks/
# │   │   │           └── JB pre-treatment.jpg
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── landmarks/
# │   │   │   │   │   ├── NE-Post-Treatment-20221215-Slices056-Frame004.jpg
# │   │   │   │   │   ├── RoiSet-Frame001.zip
# │   │   │   │   │   └── RoiSet-Frame002.zip
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── landmarks/
# │   │   │       │   ├── NE-Pre-Treatment-20221026-Slices054-Frame004.jpg
# │   │   │       │   ├── RoiSet-Frame001.zip
# │   │   │       │   └── RoiSet-Frame002.zip
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── landmarks/
# │   │       │   │   ├── RICE001-20221026-Slices054-Frame004.jpg
# │   │       │   │   ├── RoiSet-Frame001.zip
# │   │       │   │   └── RoiSet-Frame002.zip
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── landmarks/
# │   │           │   ├── RICE001-20221215-Slice056-Frame004.jpg
# │   │           │   ├── RoiSet-Frame001.zip
# │   │           │   └── RoiSet-Frame002.zip
# │   │           └── RICE001-20221215.nii.gz
# │   └── description.json
# ├── Test001/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   ├── CR-Post-Treatment-20230120.nii.gz
# │   │   │   │   ├── slice111.csv
# │   │   │   │   └── slice112.csv
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 0073-0471-0591.roi
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       ├── CR-Pre-Treatment-20221212.nii.gz
# │   │   │       ├── RoiSet.zip
# │   │   │       ├── TumourSI_Slice105.csv
# │   │   │       └── tumourSI_slice105.roi
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   ├── parameters/
# │   │   ├── Par0032_bsplines.txt
# │   │   └── Par0032_rigid.txt
# │   └── rois/
# │       ├── CR-Pre-Treatment-20221212-box-tumour.zip
# │       └── CR-Pre-Treatment-20221212-tumour.zip
# ├── Test002/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       ├── CR-Pre-Treatment-20221212.nii.gz
# │   │   │       ├── TumourSI_Slice105.csv
# │   │   │       └── tumourSI_slice105.roi
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       ├── Par0032_bsplines.txt
# │       └── Par0032_rigid.txt
# ├── Test003/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       ├── Par0032_bsplines.txt
# │       └── Par0032_rigid.txt
# ├── Test004/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       ├── Par0032_bsplines.txt
# │       └── Par0032_rigid.txt
# ├── Test005/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   ├── random_seed_42_run001_TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   │   ├── random_seed_42_run002_TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   │   ├── Test_ConstantRandomSeed_concat_volume.nii.gz
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── TP01_FIXED_601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── TP02_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── TP03_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── TP04_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── TP05_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── TP06_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── TP01_FIXED_601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── TP02_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── TP03_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── TP04_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── TP05_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── TP06_MOVED_WRT_TPOINT01_601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── TP01_FIXED_301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── TP02_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── TP03_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── TP04_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── TP05_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── TP06_MOVED_WRT_TPOINT01_301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       └── DefaultANTspy.json
# ├── Test006/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# ...
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       └── DefaultANTspy.json
# ├── Test009/
# │   ├── datasets/
# │   │   ├── CR-ANON68760/
# │   │   │   ├── CR-Post-Treatment-20230120/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── CR-Post-Treatment-20230120.nii.gz
# │   │   │   └── CR-Pre-Treatment-20221212/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── CR-Pre-Treatment-20221212.nii.gz
# │   │   ├── DC-ANON97378/
# │   │   │   ├── DC-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── DC-Post-Treatment-20230726.nii.gz
# │   │   │   └── DC-Pre-Treatment-20230621/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── DC-Pre-Treatment-20230621.nii.gz
# │   │   ├── EilB-ANON98269/
# │   │   │   ├── EilB-Post-Treatment-20230726/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── EilB-Post-Treatment-20230726.nii.gz
# │   │   │   └── EilB-Pre-Treatment-20230621/
# │   │   │       ├── 501/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 501_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 501_dyn_ethrive.nii.gz
# │   │   │       └── EilB-Pre-Treatment-20230621.nii.gz
# │   │   ├── GL-ANON99397/
# │   │   │   └── GL-Post-Treatment-20230720/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── GL-Post-Treatment-20230720.nii.gz
# │   │   ├── JB-ANON18218/
# │   │   │   ├── JB-Post-Treatment-20230511/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── JB-Post-Treatment-20230511.nii.gz
# │   │   │   └── JB-Pre-Treatment-20230405/
# │   │   │       ├── 301/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 301_dyn_ethrive.nii.gz
# │   │   │       └── JB-Pre-Treatment-20230405.nii.gz
# │   │   ├── NE-ANON89073/
# │   │   │   ├── NE-Post-Treatment-20221215/
# │   │   │   │   ├── 301/
# │   │   │   │   │   ├── 1/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 2/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 3/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 4/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   ├── 5/
# │   │   │   │   │   │   └── 301_dyn_ethrive.nii.gz
# │   │   │   │   │   └── 6/
# │   │   │   │   │       └── 301_dyn_ethrive.nii.gz
# │   │   │   │   └── NE-Post-Treatment-20221215.nii.gz
# │   │   │   └── NE-Pre-Treatment-20221026/
# │   │   │       ├── 601/
# │   │   │       │   ├── 1/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 2/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 3/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 4/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   ├── 5/
# │   │   │       │   │   └── 601_dyn_ethrive.nii.gz
# │   │   │       │   └── 6/
# │   │   │       │       └── 601_dyn_ethrive.nii.gz
# │   │   │       └── NE-Pre-Treatment-20221026.nii.gz
# │   │   └── RICE00-RICE001/
# │   │       ├── RICE001-20221026/
# │   │       │   ├── 601/
# │   │       │   │   ├── 1/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 2/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 3/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 4/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   ├── 5/
# │   │       │   │   │   └── 601_dyn_ethrive.nii.gz
# │   │       │   │   └── 6/
# │   │       │   │       └── 601_dyn_ethrive.nii.gz
# │   │       │   └── RICE001-20221026.nii.gz
# │   │       └── RICE001-20221215/
# │   │           ├── 301/
# │   │           │   ├── 1/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 2/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 3/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 4/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   ├── 5/
# │   │           │   │   └── 301_dyn_ethrive.nii.gz
# │   │           │   └── 6/
# │   │           │       └── 301_dyn_ethrive.nii.gz
# │   │           └── RICE001-20221215.nii.gz
# │   ├── description.json
# │   └── parameters/
# │       ├── Par0032_bsplines.txt
# │       └── Par0032_rigid.txt
# └── Test010/
#     ├── datasets/
#     │   └── NE-ANON89073/
#     │       └── NE-Pre-Treatment-20221026/
#     │           ├── 2024-03-16-Scene.mrml
#     │           ├── 2024-03-16-Scene.png
#     │           ├── 601-001-mask.nii.gz
#     │           ├── 601-001-masked-volume.nii.gz
#     │           ├── 601_001_N4ITK-corrected.nii.gz
#     │           ├── 601_001_N4ITK_BiasField.nii.gz
#     │           ├── Isodose_ColorTable_DefaultCopy.ctbl
#     │           └── NE-Pre-Treatment-20221026.nii.gz
#     └── description.json

# %%
# TEST000 contains just the raw (unregistered) data. Any other tests is described in the corresponding descrption.json file
tests_available = sorted(list_folder_content(input_path))
if not BATCHMODE:
    default_idx_test = 0
    print('Select a folder from the tests available:')
    display_folder_list(tests_available)
    test_idx = input(f'Pick a valid index to select a Test folder {tuple(range(len(tests_available)))} or type "x" to use the default:')
    if test_idx == 'x':
        print(f'Selecting index {default_idx_test} (default value)')
        test_idx = default_idx_test
    else:
        test_idx = int(test_idx)
    tests_to_process = [tests_available[test_idx]]
    print(f'Will process test {tests_to_process[0]}')
else:
    tests_to_process = tests_available
    print('Will process all test data in the folder:')
    print('\n'.join(tests_to_process))
# Out:
# Will process all test data in the folder:
# Test000
# Test001
# Test002
# Test003
# Test004
# Test005
# Test006
# Test007
# Test008
# Test009
# Test010

# %%
# Within Test the image data is in DATASETS and here we pick up a patient and will process all visits
if not BATCHMODE:
    path_to_patients = os.path.join(input_path, tests_to_process[0], IMGSRCFLDR)
    patient_list = sorted(list_folder_content(path_to_patients))
    default_idx_patient = 0
    print('Select a a patient from the list:')
    display_folder_list(patient_list)

    patient_idx = input(f'Pick a valid index to select a Patient {tuple(range(len(patient_list)))} or type "x" to use the default:')
    if patient_idx == 'x':
        print(f'Selecting index {default_idx_patient} (default value)')
        patient_idx = default_idx_patient
    else:
        patient_idx = int(patient_idx)
    patients_to_process = [patient_list[patient_idx]]

    print(f'Will process Patient {patients_to_process[0]}')
# else:
    # If running in Batch Mode, the patient list should be defined from the content on each test folder, i.e. inside the processing loop, not here
    # path_to_refdataset = os.path.join(input_path, REFTEST, IMGSRCFLDR)
    # patients_to_process = sorted(list_folder_content(path_to_refdataset))
    # print('Will process the patient data on each Test folder')
# Out:
# Will process the patient data on each Test folder

# %%
# Setup DataFrame to store the results
statistics = {'mi': 'Mutual Information',
              'mean_sq': 'Mean Squares', 
              'dist_corr':'Correlation', 
              'mattes_mi':'Mattes Mutual Information', 
              'joint_hist_mi':'Joint Histogram Mutual Information'}
sampling_fraction = 0.5

hdr_row = ['TestNro', 'PatientID','PatientVisit', 'FixedVolume', 'Registered2Itself', 'TimePoint'] + list(statistics.values())

stats_rows = []

# %%
# Now loop over the test(s) and patient(s) - even if not running in Batch Mode (in this case is a list of size 1, which can still be looped through)
print(f'Time at the start: {time.ctime()}')
init_time = time.perf_counter()
for test_to_process in tests_to_process:
    # Load the description file from the corresponding test: 
    description = json.loads(open(os.path.join(input_path, test_to_process, 'description.json')).read())
    # Identify the fixed volume (remember that the index is volume-1)
    reference_volume = description['Registration Details']['reference volume']
    is_reg_to_itself = description['Registration Details']['register fixed']
    ref_vol_idx = reference_volume - 1
    path_to_dataset = os.path.join(input_path, test_to_process, IMGSRCFLDR)
    if BATCHMODE:
        patient_list = sorted(list_folder_content(path_to_dataset))

    for patient_to_process in patients_to_process:
        folders_in_patient = os.path.join(path_to_dataset, patient_to_process)
        visits = list_folder_content(folders_in_patient)
        for visit in visits:
            path_to_nii = os.path.join(folders_in_patient, visit)
            nii_folder_name = '.'.join([visit, 'nii','gz'])
            nii_full_path =  os.path.join(path_to_nii, nii_folder_name)
            # Does the 4D volume exist?
            exist_nii = os.path.isfile(nii_full_path)
            if exist_nii:
                print(f'Processing file {nii_full_path}  ({test_to_process}, {nii_folder_name}), please wait...')
                # Load the volume:
                if DEBUGMODE:
                        print(''.join(['*']*100))
                        print('Timing IMAGE_READ (vol_to_proc)...')
                        start_time = time.perf_counter()
                vol_to_process = ants.image_read(nii_full_path)
                spacing, origin = [vol_to_process.spacing[:-1], vol_to_process.origin[:-1]]
                if DEBUGMODE:
                        end_time = time.perf_counter()
                        elp_time = end_time - start_time
                        print(f'\tElapsed time: {elp_time:0.2f}[s]')
                        print(''.join(['*']*100))

                # To ensure a comparable comparison across tests, load the reference volume from the unregistered data:
                print(f"path to fixed volume: {nii_full_path.replace(test_to_process,'Test000')}")
                if DEBUGMODE:
                        print(''.join(['*']*100))
                        print('Timing IMAGE_READ (fixed_volume)...')
                        start_time = time.perf_counter()
                fixed_volume = ants.image_read(nii_full_path.replace(test_to_process,'Test000'))
                if DEBUGMODE:
                        end_time = time.perf_counter()
                        elp_time = end_time - start_time
                        print(f'\tElapsed time: {elp_time:0.2f}[s]')
                        print(''.join(['*']*100))

                # ref_vol = vol_to_process[:, :, :, ref_vol_idx]
                ref_vol = fixed_volume[:, :, :, ref_vol_idx] 
                if DEBUGMODE:
                        print(''.join(['*']*100))
                        print('Timing Image Conversion FROM_NUMPY (fixed_volume)...')
                        start_time = time.perf_counter()
                ref_3d = ants.from_numpy(ref_vol, 
                                        spacing=spacing,
                                        origin=origin)
                if DEBUGMODE:
                        end_time = time.perf_counter()
                        elp_time = end_time - start_time
                        print(f'\tElapsed time: {elp_time:0.2f}[s]')
                        print(''.join(['*']*100))

                for idx_time in range(vol_to_process.shape[-1]):
                    if DEBUGMODE:
                            print(''.join(['*']*100))
                            print('Timing Image Conversion FROM_NUMPY (moving_volume)...')
                            start_time = time.perf_counter()
                    mov_3d = ants.from_numpy(vol_to_process[:,:,:,idx_time],
                                            spacing=spacing, 
                                            origin=origin)
                    print(f'Comparison between t[{ref_vol_idx+1}] & t[{idx_time+1}]:')
                    row_to_append = [test_to_process, patient_to_process, visit, reference_volume, is_reg_to_itself, idx_time+1]
                    if DEBUGMODE:
                            end_time = time.perf_counter()
                            elp_time = end_time - start_time
                            print(f'\tElapsed time: {elp_time:0.2f}[s]')
                            print(''.join(['*']*100))
                    if DEBUGMODE:
                            print(''.join(['*']*100))
                            print('Timing Stats calculation ...')
                            start_time = time.perf_counter()
                    for statsID, statsName in statistics.items():
                        statsVal = get_metrics(ref_3d, mov_3d, metric=statsID, debug=DEBUGMODE, sampling_pc=sampling_fraction)
                        row_to_append.append(statsVal)
                    if idx_time == ref_vol_idx:
                        print('(As positive control, the metric(s) are also calculated between the fixed volume and itself)')
                    if DEBUGMODE:
                        end_time = time.perf_counter()
                        elp_time = end_time - start_time
                        print(f'\tElapsed time: {elp_time:0.2f}[s]')
                        print(row_to_append)
                        print(''.join(['*']*100))

                    stats_rows.append(row_to_append)
            else:
                print(f'File {nii_folder_name} in {path_to_nii} does not exist, nothing done')
                continue
            print('Just taking a break...')
            time.sleep(1)
            print('ok, ready to go...')

final_time = time.perf_counter()
print('Creating the dataframe and saving the results...')
df = pd.DataFrame(columns=hdr_row, data=stats_rows)
df.head
if BATCHMODE:
    csv_filename = f'summary_results_metric_sampling_{sampling_fraction}.csv'
else:
    csv_filename = f'summary_results_{tests_to_process[0]}_{patients_to_process[0]}.csv'
df.to_csv(os.path.join(save_path, csv_filename), index_label='IdxKey')
elapsed_time = final_time - init_time
print(f'Elapsed time to summarise the datasets: {elapsed_time:0.2f}[s] ({timedelta(seconds=elapsed_time)})')
print(f'Time at the end: {time.ctime()}')
print('All done, check the results. Bye!')
# Out:
# Time at the start: Fri Mar 22 23:22:13 2024
# Processing file /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/CR-ANON68760/CR-Pre-Treatment-20221212/CR-Pre-Treatment-20221212.nii.gz  (Test000, CR-Pre-Treatment-20221212.nii.gz), please wait...
# ****************************************************************************************************
# Timing IMAGE_READ (vol_to_proc)...
# 	Elapsed time: 3.50[s]
# ****************************************************************************************************
# path to fixed volume: /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/CR-ANON68760/CR-Pre-Treatment-20221212/CR-Pre-Treatment-20221212.nii.gz
# ****************************************************************************************************
# Timing IMAGE_READ (fixed_volume)...
# 	Elapsed time: 2.84[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (fixed_volume)...
# 	Elapsed time: 0.09[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[1]:
# 	Elapsed time: 0.42[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.96[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.65[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.83[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.92[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 34.01[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 2, False, 1, -0.5073886960485164, 178489.015625, -0.5936515927314758, -0.6297764778137207, -0.303646057844162]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[2]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.62[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.31[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.56[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.87[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.17[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# (As positive control, the metric(s) are also calculated between the fixed volume and itself)
# 	Elapsed time: 33.54[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 2, False, 2, -1.1645617881157628, 0.0, -1.0, -1.45902419090271, -0.4601183831691742]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[3]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.69[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.49[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.55[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.83[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.86[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.41[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 2, False, 3, -0.6231609011848945, 72936.0, -0.8308984041213989, -0.7584593296051025, -0.35206109285354614]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[4]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.65[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.31[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.50[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.83[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.99[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.29[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 2, False, 4, -0.6272523773694277, 67768.484375, -0.8403981924057007, -0.764949381351471, -0.3554946482181549]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[5]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.67[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.32[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.55[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.79[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.87[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.20[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 2, False, 5, -0.6235160909004336, 68223.953125, -0.8389508724212646, -0.760520339012146, -0.35129648447036743]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[6]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.31[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.52[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.86[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.85[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.20[s]
# ['Test000', 'CR-ANON68760', 'CR-Pre-Treatment-20221212', 2, False, 6, -0.5902991039234096, 85642.4375, -0.798643171787262, -0.7222625017166138, -0.33535388112068176]
# ****************************************************************************************************
# Just taking a break...
# ok, ready to go...
# Processing file /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/CR-ANON68760/CR-Post-Treatment-20230120/CR-Post-Treatment-20230120.nii.gz  (Test000, CR-Post-Treatment-20230120.nii.gz), please wait...
# ****************************************************************************************************
# Timing IMAGE_READ (vol_to_proc)...
# 	Elapsed time: 3.27[s]
# ****************************************************************************************************
# path to fixed volume: /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/CR-ANON68760/CR-Post-Treatment-20230120/CR-Post-Treatment-20230120.nii.gz
# ****************************************************************************************************
# Timing IMAGE_READ (fixed_volume)...
# 	Elapsed time: 2.76[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (fixed_volume)...
# 	Elapsed time: 0.06[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[1]:
# 	Elapsed time: 0.37[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.17[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.54[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.54[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.76[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.85[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.86[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 2, False, 1, -0.4974622358769965, 252889.390625, -0.5848492383956909, -0.6239409446716309, -0.2810923457145691]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[2]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.67[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.31[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.50[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.79[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.97[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# (As positive control, the metric(s) are also calculated between the fixed volume and itself)
# 	Elapsed time: 33.23[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 2, False, 2, -1.0882097429455053, 0.0, -1.0, -1.383167028427124, -0.39157938957214355]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[3]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.65[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.33[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.46[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.80[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.92[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.16[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 2, False, 3, -0.6147213879194189, 87854.015625, -0.8514161109924316, -0.7564657330513, -0.30847257375717163]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[4]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.38[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.50[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.64[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.79[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 32.97[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 2, False, 4, -0.5817726573618479, 116981.3515625, -0.8035442233085632, -0.7176909446716309, -0.3101367652416229]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[5]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.65[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.35[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.49[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.79[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.94[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.22[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 2, False, 5, -0.5686501872521579, 124128.2734375, -0.7907867431640625, -0.7038456201553345, -0.30188998579978943]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[6]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.68[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.37[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.49[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.82[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.92[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.28[s]
# ['Test000', 'CR-ANON68760', 'CR-Post-Treatment-20230120', 2, False, 6, -0.5796522655755436, 117991.28125, -0.7997406721115112, -0.7158591151237488, -0.32026931643486023]
# ****************************************************************************************************
# Just taking a break...
# ok, ready to go...
# Processing file /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/DC-ANON97378/DC-Pre-Treatment-20230621/DC-Pre-Treatment-20230621.nii.gz  (Test000, DC-Pre-Treatment-20230621.nii.gz), please wait...
# ****************************************************************************************************
# Timing IMAGE_READ (vol_to_proc)...
# 	Elapsed time: 1.19[s]
# ****************************************************************************************************
# path to fixed volume: /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/DC-ANON97378/DC-Pre-Treatment-20230621/DC-Pre-Treatment-20230621.nii.gz
# ****************************************************************************************************
# Timing IMAGE_READ (fixed_volume)...
# 	Elapsed time: 1.09[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (fixed_volume)...
# 	Elapsed time: 0.03[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[1]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 0.98[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.63[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.67[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.76[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.81[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 11.86[s]
# ['Test000', 'DC-ANON97378', 'DC-Pre-Treatment-20230621', 2, False, 1, -0.41960020043918056, 200499.328125, -0.6590184569358826, -0.580603837966919, -0.26152893900871277]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[2]:
# 	Elapsed time: 0.02[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 0.97[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.60[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.69[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.75[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.80[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# (As positive control, the metric(s) are also calculated between the fixed volume and itself)
# 	Elapsed time: 11.81[s]
# ['Test000', 'DC-ANON97378', 'DC-Pre-Treatment-20230621', 2, False, 2, -0.9292922156108359, 0.0, -1.0, -1.2232638597488403, -0.3852570950984955]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[3]:
# 	Elapsed time: 0.02[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 0.97[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.60[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.76[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.83[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 11.82[s]
# ['Test000', 'DC-ANON97378', 'DC-Pre-Treatment-20230621', 2, False, 3, -0.5254097949002909, 65831.0, -0.8588093519210815, -0.6936172842979431, -0.29605627059936523]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[4]:
# 	Elapsed time: 0.02[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 1.01[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.58[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.76[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.80[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 11.82[s]
# ['Test000', 'DC-ANON97378', 'DC-Pre-Treatment-20230621', 2, False, 4, -0.5369208890820505, 67230.0234375, -0.8558094501495361, -0.7062594890594482, -0.3075222969055176]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[5]:
# 	Elapsed time: 0.02[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 0.96[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.58[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.75[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.79[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 11.75[s]
# ['Test000', 'DC-ANON97378', 'DC-Pre-Treatment-20230621', 2, False, 5, -0.543058349857525, 62115.8359375, -0.8666324019432068, -0.7142337560653687, -0.34085872769355774]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[6]:
# 	Elapsed time: 0.02[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 0.97[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.58[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.65[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.75[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.84[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 11.78[s]
# ['Test000', 'DC-ANON97378', 'DC-Pre-Treatment-20230621', 2, False, 6, -0.5095209928759759, 79911.2734375, -0.8290441036224365, -0.6760863661766052, -0.31376951932907104]
# ****************************************************************************************************
# Just taking a break...
# ok, ready to go...
# Processing file /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/DC-ANON97378/DC-Post-Treatment-20230726/DC-Post-Treatment-20230726.nii.gz  (Test000, DC-Post-Treatment-20230726.nii.gz), please wait...
# ****************************************************************************************************
# Timing IMAGE_READ (vol_to_proc)...
# 	Elapsed time: 1.14[s]
# ****************************************************************************************************
# path to fixed volume: /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/DC-ANON97378/DC-Post-Treatment-20230726/DC-Post-Treatment-20230726.nii.gz
# ****************************************************************************************************
# Timing IMAGE_READ (fixed_volume)...
# 	Elapsed time: 1.06[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (fixed_volume)...
# 	Elapsed time: 0.02[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[1]:
# 	Elapsed time: 0.10[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 0.97[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# ...
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.91[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.87[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.74[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.89[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.98[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 34.40[s]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 2, False, 1, -0.36329299001426374, 295712.0, -0.5049213767051697, -0.48898306488990784, -0.2584514021873474]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[2]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.67[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.55[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.71[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.10[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.03[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# (As positive control, the metric(s) are also calculated between the fixed volume and itself)
# 	Elapsed time: 34.06[s]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 2, False, 2, -1.054519581565251, 0.0, -1.0, -1.3448408842086792, -0.4273357093334198]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[3]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.74[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.39[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.59[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.89[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.10[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.71[s]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 2, False, 3, -0.5564263844571328, 85679.6953125, -0.8509883284568787, -0.6967272758483887, -0.3312039077281952]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[4]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.68[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.31[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.55[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.85[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.98[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.38[s]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 2, False, 4, -0.553335743786216, 86733.015625, -0.8479310274124146, -0.6936282515525818, -0.3369003236293793]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[5]:
# 	Elapsed time: 0.11[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.36[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.66[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.93[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.15[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.76[s]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 2, False, 5, -0.5434794820173134, 93297.40625, -0.8363708257675171, -0.6823153495788574, -0.3396240472793579]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[6]:
# 	Elapsed time: 0.12[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 2.70[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.40[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric dist_corr...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.60[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mattes_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 7.92[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric joint_hist_mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 8.00[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# 	Elapsed time: 33.62[s]
# ['Test000', 'NE-ANON89073', 'NE-Pre-Treatment-20221026', 2, False, 6, -0.5399645716668711, 95257.8984375, -0.8314126133918762, -0.6793033480644226, -0.3391607403755188]
# ****************************************************************************************************
# Just taking a break...
# ok, ready to go...
# Processing file /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/NE-ANON89073/NE-Post-Treatment-20221215/NE-Post-Treatment-20221215.nii.gz  (Test000, NE-Post-Treatment-20221215.nii.gz), please wait...
# ****************************************************************************************************
# Timing IMAGE_READ (vol_to_proc)...
# 	Elapsed time: 3.26[s]
# ****************************************************************************************************
# path to fixed volume: /Users/joseulloa/Data/fMRIBreastData/tests/Test000/datasets/NE-ANON89073/NE-Post-Treatment-20221215/NE-Post-Treatment-20221215.nii.gz
# ****************************************************************************************************
# Timing IMAGE_READ (fixed_volume)...
# 	Elapsed time: 2.78[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (fixed_volume)...
# 	Elapsed time: 0.07[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Image Conversion FROM_NUMPY (moving_volume)...
# Comparison between t[2] & t[1]:
# 	Elapsed time: 0.39[s]
# ****************************************************************************************************
# ****************************************************************************************************
# Timing Stats calculation ...
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mi...
# §§§§§§§§§§§§ GET_METRICS: Elapsed time: 3.11[s]
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# §§§§§§§§§§§§ GET_METRICS: Timing the calculations of metric mean_sq...

# %%
if BATCHMODE:
    csv_filename = f'summary_results_metric_sampling_{sampling_fraction}.csv'
else:
    csv_filename = f'summary_results_{tests_to_process[0]}_{patients_to_process[0]}.csv'
df.to_csv(os.path.join(save_path, csv_filename), index_label='IdxKey')
elapsed_time = final_time - init_time
print(f'Elapsed time to summarise the datasets: {elapsed_time:0.2f}[s] ({timedelta(seconds=elapsed_time)})')
print(f'Time at the end: {time.ctime()}')
print('All done, check the results. Bye!')
# Out:
# Elapsed time to summarise the datasets: -115.75[s] (-1 day, 23:58:04.249210)
# Time at the end: Fri Mar 22 22:59:48 2024
# All done, check the results. Bye!
